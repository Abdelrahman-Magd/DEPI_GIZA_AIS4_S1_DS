# %%
txt = "hello Dr . George samuel"
print(txt.title())
# Out:
# Hello Dr . George Samuel

# %%
#Task_1 Email Address

email = input ("Enter your email address: ")

##Input validation
if email.count("@") == 1 and email.count(".") >= 1:
    print("Valid email address")
    username = email.split("@")[0]
    print("Username:", username)       ##Username extraction   
    domain = email.split("@")[1].split(".")[0]
    print("Domain:", domain)           ##Domain extraction
    if email.endswith(".com"):        ##check for domain endings
        print("This is a commercial email address.")
    elif email.endswith(".edu"):
        print("This is an educational email address.")
    else :
        print("This is a different type of email address.")
else:
    print("Invalid email address")
# Out:
# Valid email address
# Username: abdalrahmanmagd03
# Domain: gmail
# This is a commercial email address.

# %%
#Task_2 Encoded Message
message_1 = ("###!!@mocleW EPGTQ!!!6789") 
core_message = message_1[6:-7:1]
print(core_message)        # 1. Extract the core part of the message: "mocleW EPGTQ".




words = core_message.split()
print(words)
reversed_word_1 = words[0][::-1]
print(reversed_word_1)
list_char = list(reversed_word_1)
print(list_char)
list_char.append("e")
print(list_char)
fixed_word = "".join(list_char)
print(fixed_word)         # 2. Reverse the first word: "mocleW" becomes "Welcome".




second_word = words[1]
fix = second_word.removeprefix("E")
print(fix)                # 3. Remove shifted vowels in the second word

final_message_2 = fixed_word + " " + fix
print(final_message_2)    # 4. Final decoded message: "Welcome PGTQ"
# Out:
# mocleW EPGTQ
# ['mocleW', 'EPGTQ']
# Welcom
# ['W', 'e', 'l', 'c', 'o', 'm']
# ['W', 'e', 'l', 'c', 'o', 'm', 'e']
# Welcome
# PGTQ
# Welcome PGTQ

# %%
#Task_3 Encoded Message
message_3 = ("&&&**$gnirtS PLIO!!@1234")
core_message = message_3[6:-7:1]
print(core_message)      # 1. Extract the core part of the message: "gnirtS PLIO".




words = core_message.split()
print(words)
reversed_word = words[0][::-1]
print(reversed_word)     # 2. Reverse the first word: "gnirtS" becomes "String".




second_word = words[1]
fix = second_word.replace("PLIO", "PLEU")
print(fix)               # 3. Replace shifted vowels in the second word:




final_message = reversed_word + " " + fix
print(final_message)     # 4. Final decoded message: "String PLEU".
# Out:
# gnirtS PLIO
# ['gnirtS', 'PLIO']
# String
# PLEU
# String PLEU

# %%
#Task_4 Encoded Message
message_4 = ("##$$$@!yalpstcejorp EPUVT****9887")
core_message = message_4[7:-8:1]
print(core_message)      # 1. Extract the core part of the message: 



words = core_message.split()
print(words)            
reversed_word = words[0][::-1]
print(reversed_word)     # 2. Reverse the first word: "yalpstcejorp" becomes "projectsplay".




second_word = words[1]
fix = second_word.replace("EPUVT", "APOVT") 
print(fix)               # 3. Replace shifted vowels in the second word:




final_message = reversed_word + " " + fix
print(final_message)     # 4. Final decoded message: "projectsplay APOVT".
# Out:
# yalpstcejorp EPUVT
# ['yalpstcejorp', 'EPUVT']
# projectsplay
# APOVT
# projectsplay APOVT

# %%
###End of tasks
