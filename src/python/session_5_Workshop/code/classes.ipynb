# %%
class A:
    
    def do_this(self):
        print("A")

class B(A):
    pass

class C:
    def do_this(self):
        print("C")
    
class D(B,C):

    pass

# %%
x = D()
x.do_this()
# Out:
# A
