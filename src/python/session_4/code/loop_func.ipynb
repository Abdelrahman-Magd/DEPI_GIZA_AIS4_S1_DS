# %%
import random
n = random.random()

def calc_degree(n):
    print(n**n)



calc_degree(n)
# Out:
# 0.900084155124072

# %% [markdown]
# Choose randomly from a list

# %%
import random
list = ["Ahmed","Ali","Omar", 1, 3, 8]
random.choice(list)
# Out:
# 'Ali'

# %%
list = ["Ahmed","Ali","Omar", 1, 3, 8]
random.choices(list, k = 4)
# Out:
# [8, 'Ali', 'Ali', 'Ahmed']

# %% [markdown]
# Read File

# %%
import os
import sys  
# f = open("")
# print(f.read())
# f.close

# %%
base = "D:/DEPI/DEPI_GIZA_AIS4_S1_DS/src/python/session_4/code"

# %%
type(base)
# Out:
# str

# %%
import os 
file= os.listdir(base)

print(file)
# Out:
# ['loop_func.ipynb']

# %%
import random
random.choice(file)
# Out:
# 'loop_func.ipynb'

# %% [markdown]
# join pathes

# %%
base_dir = "./tmp_directory"
file_name = "text_1.txt"
file_path = os.path.join(base_dir , file_name)
file_path
# Out:
# './tmp_directory\\text_1.txt'

# %% [markdown]
# remove file

# %%
# os.remove(base='/rem.text')
base_dir = "./tmp_directory"
file_name = "text_1.txt"
file_path = os.path.join(base_dir , file_name)

os.remove(file_path)

# %% [markdown]
# add new directory

# %%
import os
directory = "./tmp_directory_test_again"

if not os.path.exists(directory):
    os.makedirs(directory)
else:
    print("Directory already exists ;" , directory)
# Out:
# Directory already exists ; ./tmp_directory_test_again

# %%
import os
path = "tmp_directory_test_again"
if not os.path.exists(path):
    os.makedirs(path)
for i in range(20):
    inner_path = os.path.join(path ,"dir_"+ str(i))
    if not os.path.exists(inner_path):
        os.makedirs(inner_path)



def create_folders(path):
    
    if not os.path.exists(path):
        os.makedirs(path)
    for i in range(20):
        inner_path = os.path.join(path ,"dir_"+ str(i))
        if not os.path.exists(inner_path):
            os.makedirs(inner_path)

# %%
from create_folder import create_folders
create_folders(path)

# %% [markdown]
# File Handling

# %%
from create_folder import create_folders

# %% [markdown]
# open a file using "with" clause

# %%
with open("./tmp_directory/text_1.txt" , "a+") as file:
    file.write(" New line added\n")

    file.seek(0)

    updated_content = file.read()

    print(updated_content)
# Out:
#  New line added
#  New line added

# %%
try:
    5/0
except :
    print("not accept to divide by zero")
# Out:
# not accept to divide by zero

# %%
try:
    x = 10
    y = int(input())
    x/y
except :
    print("Division by zero")
# Out:
# Division by zero

# %%
try:
    5/0
except Exception as e:
    print(e)
# Out:
# division by zero

# %% [markdown]
# *OOP*

# %%
"""""
this class

"""
class StudentInfo:

    def __init__(self,student_name,age,GPA,gender):
        self.student_name = student_name
        self.age = age
        self.GPA = GPA
        self.gender = gender


    def student_info(self):
        return f"welcome {self.student_name}"

# %%
s1 = StudentInfo("Maggo",21,3.99,"male")
s1.student_info()
# Out:
# 'welcome Maggo'

# %%
class test:
    def info(self):
        print(self)

# %%
t1 = test()
print(t1)
print(t1.info())
# Out:
# <__main__.test object at 0x000001289EABE120>
# <__main__.test object at 0x000001289EABE120>
# None

# %%
class Calc:

    def __init__(self, num1, num2):
        self.num1 = num1
        self.num2 = num2

    def sum(self):
        return self.num1 + self.num2
    def sub(self):
        return self.num1 - self.num2

# %%
c1 = Calc(5,3)
c1.sum()
# Out:
# 8

# %%
from abc import ABC, abstractmethod


class Animal(ABC):

    @abstractmethod
    def move(self):
        pass


class Bird(Animal):
    def move(self):
        print("bird")



class Cat(Animal):
    def move(self):
        print("cat")

# %%
a = Bird()
a.move()
# Out:
# bird
