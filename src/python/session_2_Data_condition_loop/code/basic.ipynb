# %%
list_one  = [1, 2, 3, 4, "DEPI","learning",True,[1,2,3,"True",["ml","DL","ds"]]]
print(list_one)
print(type(list_one))
# Out:
# [1, 2, 3, 4, 'DEPI', 'learning', True, [1, 2, 3, 'True', ['ml', 'DL', 'ds']]]
# <class 'list'>

# %%
list_one [0]
# Out:
# 1

# %%
name = "George"
print(type(name))
list_1 = list(name)
print(list_1)
# Out:
# <class 'str'>
# ['G', 'e', 'o', 'r', 'g', 'e']

# %%
num = 5,6
list(num)
# Out:
# [5, 6]

# %%
list_1 = [1,2,3]
list_1.append(5)
print(list_1)
# Out:
# [1, 2, 3, 5]

# %%
list_2 = ["depi","learning","python"]

# %%
list_2.insert(0,"AMIT")
print(list_2)
# Out:
# ['AMIT', 'depi', 'learning', 'python', 5]

# %%
list_1 = [1,2,3]
list_2 = [4,5,6]
list_1.extend(list_2)
print(list_1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list_1 = ["depi","learning","learning","python"]
new = list_1.pop(0)
print(list_1)
# Out:
# ['learning', 'learning', 'python']

# %%
del list_1[0]

# %%
list_1
# Out:
# ['learning', 'python']

# %%
name = input()
print(type(name))
# Out:
# <class 'str'>

# %%
name = input("Enter your name: ")
id = input("Enter your ID: ")
print(f"my name is {name} and my ID is {id}")
# Out:
# my name is maggo and my ID is 555

# %%
list_new = ["depi","learning","python"]
item = input("Enter your value ")
list_new.remove(item)
print(f"output list = {list_new}")
# Out:
# output list = ['learning', 'python']

# %%
my_list = [1,2,2,3]
my_list.count(2)
# Out:
# 2

# %%
my_tuple_2 = [50,20,48,30,1,19]

# %%
name = "George"
tuple_1 = tuple(name)
print(tuple_1)
# Out:
# ('G', 'e', 'o', 'r', 'g', 'e')

# %%
color ={"red":1}
print(type(color))
# Out:
# <class 'dict'>

# %%
set_a = {1,2,3}
set_b = {3,4,5}
print(set_a.difference(set_b))
# Out:
# {1, 2}

# %%
dict_1 = {"key1":12,"key2":"python"}
print(type(dict_1))
dict_1["key1"] = 12.9
print(dict_1)
# Out:
# <class 'dict'>
# {'key1': 12.9, 'key2': 'python'}

# %%
Key_dict = [("a",1),("b",2),("c",3)]
conv_dict = dict(Key_dict)
print(conv_dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
num = int(input("Enter your number "))
type(num)
# Out:
# int

# %%
2**5
# Out:
# 32

# %%
x = 5
x += 1
x
# Out:
# 6

# %%
x = 20 
y = 5
result =(x +True) / (y + False)
result
# Out:
# 4.2

# %%
num_1 = float(input("Enter first number : "))
num_2 = float(input("Enter second number : "))
print(f"summation : {num_1 + num_2}")
print(f"subtraction : {num_1 - num_2}")
print(f"multiplication : {num_1 * num_2}")
print(f"division : {num_1 / num_2}")
# Out:
# summation : 30.0
# subtraction : -10.0
# multiplication : 200.0
# division : 0.5

# %%
a = 300
b = 33
if b > a :
    print("b is greater than a")
else :
    print("b is not greater than a")
# Out:
# b is not greater than a

# %%
# shortHand if
x = 20
result = "x is even" if x % 2 == 0 else "x is odd"
print(result)
# Out:
# x is even

# %%
a = 10
b = 5
result = a + b
