# %%
print("Hello world")
# Out:
# Hello world

# %%
name = "george"
age = 35
"my name is {} and I am {} years old".format(name, age)
# Out:
# 'my name is george and I am 35 years old'

# %%
f"my name is {name} and I am {age} years old"
# Out:
# 'my name is george and I am 35 years old'

# %%
def get_info(name, age):
 return f"my name is {name} and I am {age} years old"

# %%
name = "Depi_ds"
name[0]
# Out:
# 'D'

# %%
name = "amit learning"
print(name[0:4:1])
# Out:
# amit

# %%
name = "Depi_ds"
upper_txt = name.upper()
upper_txt
# Out:
# 'DEPI_DS'

# %%
lower_txt = upper_txt.lower()
lower_txt
# Out:
# 'depi_ds'

# %%
name = "welcome in Depi datascience journey"
x = name.split()
x
# Out:
# ['welcome', 'in', 'Depi', 'datascience', 'journey']
